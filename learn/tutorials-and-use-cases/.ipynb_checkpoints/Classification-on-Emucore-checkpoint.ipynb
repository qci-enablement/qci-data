# %% [markdown]
# # Classification on EmuCore
# #### Device: EmuCore
#
# ## Introduction
#
# In this project, we have leveraged QCi’s EmuCore reservoir technology to classify emotional speech files. Below, we provide an overview of the dataset, the approach we adopted, and the results we obtained.
#
# ### Reservoir Computing
#
# Reservoir computing is an approach that involves passing data through a randomly initialized neural network (the reservoir) and then using the processed data to train a simple linear model downstream. Unlike traditional neural networks, reservoir-based models are easier to set up and less computationally expensive to train. This method requires less domain expertise for different applications, making it highly versatile.
#
# ![Reservoir Schematic](attachment:01.svg)

# %% [markdown]
# ### Recurrent Neural Networks (RNN)
#
# In our setup, we use a Recurrent Neural Network (RNN) architecture as our reservoir. RNNs are a class of neural networks that are particularly suited for sequential data, such as speech, because they have the ability to maintain information about previous inputs.
#
# For more information on RNNs, you can visit [Recurrent Neural Networks on Wikipedia](https://en.wikipedia.org/wiki/Recurrent_neural_network).
#
# ![RNN Model](attachment:02.svg)
#
# Figure 2: A conceptual illustration of an RNN - On the left the model is shown as an input layer x, a hidden layer h, and an output layer y; the input to h is x as well the output of h from previous step. The illustration is unrolled on the right. For example, the input to h(t), hidden later at time t, is the input (t) at time t as well as the output of hidden layer at time t-1, that is h(t-1).

# %% [markdown]
# Below is a schematic representation of the RNN reservoir setup:
#
# ![RNN Reservoir Schematic](attachment:03.svg)
#
# Figure 3: A conventional reservoir computer consisting of input, reservoir, and output layers. The reservoir layer contains a large number of randomly interconnected recurrent, nonlinear nodes.
# This architecture is hard wired to accommodate RNN models.

# %% [markdown]
# ### QCi's EmuCore
#
# QCi's EmuCore technology employs a time-delayed scheme for reservoir computing. This technique allows the reservoir to capture and process temporal dependencies in the input data effectively.
#
# ![04.svg](attachment:04.svg)
#
# Figure 4: A time delay based reservoir computer. Similar to a conventional reservoir computer, the architecture includes input, reservoir, and output layers. However, the reservoir layer contains only one physical node that acts as a large set of temporally spaced virtual nodes.
#
# For more detailed information on this technology, you can refer to [this research paper](https://arxiv.org/pdf/2102.09049.pdf).

# %% [markdown]
# ## Dataset
#
# In this study, we used the RAVDESS Emotional Speech Dataset. RAVDESS
# dataset consists of 1440 audio files, generated by 24 speakers, which correspond
# to 8 different emotion. The aim is build a model that can detect which emotion
# an audio file corresponds to.
#
#
# https://www.kaggle.com/datasets/uwrfkaggler/ravdess-emotional-speech-audio
#
#
# Copy the files to a directory called "ravdess_files" under the working directory.

# %% [markdown]
# ## Method
#
# Our approach consists of the following steps,

# %%
from scipy.io import wavfile
import matplotlib.pyplot as plt
import numpy as np
import warnings
import os
import glob
from scipy.io import wavfile

# Suppress warnings to keep the output clean
warnings.filterwarnings("ignore")

# %% [markdown]
# <h3>Looking for .wav Files</h3>
# <h5>This will help find the .wav files in directories and sub-directories.

# %%
# Specify the root directory containing subfolders with .wav files
root_dir = "ravdess_files/"  # Replace the path with your Actual Path

# Dictionary to store audio data
audio_data = {}

# Iterate over all subdirectories in the root directory
for subdir, dirs, files in os.walk(root_dir):
    # For each subdirectory, get all .wav files
    wav_files = glob.glob(os.path.join(subdir, "*.wav"))

    for wav_file in wav_files:
        # Load the audio file using wavfile
        sample_rate, audio = wavfile.read(wav_file)
        # Store the audio data in the dictionary
        audio_data[wav_file] = {"audio": audio, "sample_rate": sample_rate}

# %% [markdown]
# <h3>Plotting the sample wavfile.

# %%
# Convert the audio data to a numpy array with a specific type (float64)
audio = np.array(audio, dtype=np.float64)

# Extract a specific segment of the audio data for analysis (from index 50,001 to 125,000)
audio_segment = audio[50001:125000]

# Plot the audio segment using matplotlib
plt.plot(audio_segment)
plt.show()

# %% [markdown]
# <h3> Viewing the data as cochleagram.

# %%
from lyon.calc import LyonCalc

# Create an instance of LyonCalc
calc = LyonCalc()

# Apply the Lyon passive ear model to the audio data to calculate a cochleagram
vec = calc.lyon_passive_ear(
    audio_segment,
    1.0e6,
    decimation_factor=1000,
    ear_q=8,
)

# Convert the result to a numpy array and save it to a file named 'vec.npy'
vec = np.array(vec)
np.save("vec.npy", vec)

# Plot the cochleagram using matplotlib
plt.imshow(vec)
plt.show()

# %% [markdown]
# <h3> One hot encoding of labels

# %%
def to_categorical(y, num_classes=None, dtype="float32"):
    """
    Converts a list of labels to a one-hot encoded format.

    Parameters:
    y (array-like): List of labels.
    num_classes (int): Number of classes. If None, it will be inferred from the data.
    dtype (str): Data type of the output array.

    Returns:
    np.ndarray: One-hot encoded representation of the input labels.
    """
    y = np.array(y, dtype="int")
    input_shape = y.shape

    # Reshape if the input shape is (..., 1)
    if input_shape and input_shape[-1] == 1 and len(input_shape) > 1:
        input_shape = tuple(input_shape[:-1])

    y = y.reshape(-1)
    if not num_classes:
        num_classes = np.max(y) + 1
    n = y.shape[0]
    categorical = np.zeros((n, num_classes), dtype=dtype)
    categorical[np.arange(n), y] = 1
    output_shape = input_shape + (num_classes,)
    categorical = np.reshape(categorical, output_shape)
    return categorical

# %% [markdown]
# <h3> Searching the audio files in the given directory

# %%
def search_audio_files(folder_path):
    """
    Searches for audio files in the specified directory.

    Parameters:
    folder_path (str): The path to the directory to search for audio files.

    Returns:
    list: A list of filenames of the audio files found in the directory.
    """
    file_names = [
        f for f in listdir(folder_path) if isfile(join(folder_path, f)) and ".wav" in f
    ]
    return file_names

# %% [markdown]
# <h3> Determine how to rescale sound data

# %%
def _parse_rescale_arg(rescale):
    """
    Parses the rescale argument and returns the appropriate rescale method.

    Parameters:
    rescale (str): The rescale method to use. Can be 'normalize', 'standardize', or None.

    Returns:
    str: The parsed rescale method.
    """
    if rescale is not None:
        rescale = rescale.lower()
    if rescale == "normalize":
        out_rescale = "normalize"
    elif rescale == "standardize":
        out_rescale = "standardize"
    elif rescale is None:
        out_rescale = None
    else:
        raise ValueError("Unrecognized rescale value: %s" % rescale)
    return out_rescale

# %% [markdown]
# <h3>Rescale sound data

# %%
def rescale_sound(snd_array, rescale):
    """
    Rescales the sound data according to the specified rescale method.

    Parameters:
    snd_array (np.ndarray): The sound data to rescale.
    rescale (str): The rescale method to use. Can be 'normalize' or 'standardize'.

    Returns:
    np.ndarray: The rescaled sound data.
    """
    rescale = _parse_rescale_arg(rescale)
    if rescale == "standardize":
        if issubclass(snd_array.dtype.type, np.integer):
            snd_array = snd_array / float(
                np.iinfo(snd_array.dtype).max
            )  # rescale so max value allowed by precision has value 1
        elif issubclass(snd_array.dtype.type, np.floating):
            snd_array = snd_array / float(
                np.finfo(snd_array.dtype).max
            )  # rescale so max value allowed by precision has value 1
        else:
            raise ValueError(
                "rescale is undefined for input type: %s" % snd_array.dtype
            )
    elif rescale == "normalize":
        snd_array = snd_array / float(snd_array.max())  # rescale to [-1, 1]
    return snd_array

# %% [markdown]
# <h3> Read wav files and rescale their data

# %%
def wav_to_array(fn, rescale="standardize"):
    """
    Reads a wav file and rescales its data.

    Parameters:
    fn (str): The file path to the wav file.
    rescale (str): The rescale method to use. Can be 'normalize' or 'standardize'.

    Returns:
    tuple: A tuple containing the rescaled sound data (np.ndarray) and the sample frequency (int).
    """
    samp_freq, snd = wavfile.read(fn)
    snd = rescale_sound(snd, rescale)
    return snd, samp_freq

# %% [markdown]
# <h3> Convert audio data to a cochleagram

# %%
def convert_to_cochleagram(
    audio_path, decimation_factor=77, n=None, nonlinearity=None, maxLength=None
):
    """
    Converts audio data to a cochleagram.

    Parameters:
    audio_path (str): The file path to the audio file.
    decimation_factor (int): The decimation factor for the cochleagram calculation.
    n (int): The number of frequency channels.
    nonlinearity (str): The type of nonlinearity to apply.
    maxLength (int): The maximum length of the audio data. If None, no padding is applied.

    Returns:
    tuple: A tuple containing the cochleagram (np.ndarray) and a status code (int).
    """
    signal, sample_rate = wav_to_array(audio_path)
    signal = signal[50001:125000]  # Extract a specific segment of the audio data

    fs = 12e3  # Resample frequency
    data = librosa.core.resample(
        y=signal.astype(np.float64), orig_sr=sample_rate, target_sr=fs, res_type="scipy"
    )

    # Zero padding if needed
    if maxLength is not None and len(data) > maxLength:
        err_msg = f"datalength={len(data)}, maxlength={maxLength}, data length cannot exceed padding length."
        print(err_msg)
        return (None, -1)
    elif maxLength is not None and len(data) < maxLength:
        embedded_data = np.zeros(maxLength)
        offset = np.random.randint(low=0, high=maxLength - len(data))
        embedded_data[offset : offset + len(data)] = data
    elif maxLength is not None and len(data) == maxLength:
        embedded_data = data

    if maxLength is not None:
        data = embedded_data

    calc = LyonCalc()

    # Using resampled data to create a cochleagram
    coch = calc.lyon_passive_ear(
        data,
        fs,
        decimation_factor=decimation_factor,
        ear_q=8,
    )
    coch = np.array(coch)
    return (coch, 0)

# %% [markdown]
# <h3> Calculate the accuracy of predictions

# %%
def WSR_MSE(target_lst, est_lst):
    """
    Calculates the Weighted Symbol Rate Mean Squared Error (WSR_MSE) between target and estimated labels.

    Parameters:
    target_lst (list): The list of target labels (one-hot encoded).
    est_lst (list): The list of estimated labels (one-hot encoded).

    Returns:
    float: The WSR_MSE value.
    """
    success = 0
    count = 0

    for estimate, target in zip(est_lst, target_lst):
        count += 1
        estimate_index_np_array = np.array(estimate)
        if target[np.argmax(estimate_index_np_array)] == 1:
            success += 1
    wsr = success / count
    return wsr

# %% [markdown]
# <h3> Setting up the parameters

# %% [markdown]
# Import Libraries: Bring in libraries for file handling, random number generation, timing, numerical operations, data manipulation, and plotting.
#
# Define Audio Directory: Set the path where your audio files are stored.
#
# Set Constants:
#
# NUM_LABELS: The number of different emotions that the model will recognize.
# NUM_ACTORS: The total number of actors whose voices are recorded.
# NUM_TRAIN_ACTORS: How many actors will be used to train the model.
# DECIMATION_FACTOR: A number used to process the audio data (technical detail).
# MAX_LENGTH: Maximum length of audio data; None means there is no restriction.
# Create Actor List: Make a list of actor numbers from 1 to the total number of actors.
#
# Shuffle Actors: Randomly mix up the order of the actors to ensure training data is diverse.
#
# Select Training Actors: Choose the first few actors from the shuffled list to be used in training the model.
#
# Print Training Actors: Show the list of actors selected for training to verify the choice

# %%
# Import necessary libraries for handling files, numbers, and data visualization
import os
import sys
import random
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Define the directory where audio files are stored
AUDIO_DIR = "ravdess_files/"

# Number of different emotion labels we have
NUM_LABELS = 8

# Total number of actors in the dataset
NUM_ACTORS = 24

# Number of actors to be used for training
NUM_TRAIN_ACTORS = 19

# Decimation factor used for processing audio data
DECIMATION_FACTOR = 77

# Maximum length for audio data (None means no limit)
MAX_LENGTH = None

# List of all actor numbers from 1 to NUM_ACTORS
ACTORS = [i for i in range(1, NUM_ACTORS + 1)]

# Shuffle the list of actors randomly to mix them up
random.shuffle(ACTORS)

# Select the first NUM_TRAIN_ACTORS actors from the shuffled list for training
train_actors = ACTORS[:NUM_TRAIN_ACTORS]

# Print the list of actors chosen for training
print(train_actors)
# Out:
# [19, 1, 11, 18, 21, 6, 8, 13, 7, 20, 16, 22, 23, 3, 24, 17, 12, 4, 14]

# %% [markdown]
# <h2>Loading the dataset and preparing to train the model</h2>
#
# Initialize Training and Testing Data: Sets up two dictionaries to store processed data for training and testing.
#
# Iterate Over Audio Files: Processes each audio file, extracts important details from its name, and converts it to a cochleagram.
#
# Save Cochleagram: Saves the cochleagram image for the current audio file.
#
# Check Conversion Success: If the cochleagram conversion fails, the file is skipped.
#
# Convert Emotion Label: Transforms the emotion label into a format used for machine learning (one-hot encoding).
#
# Organize Data: Adds the cochleagram and label to the appropriate set based on whether the actor is part of the training set or not.
#
# Save Data: Saves the organized training and testing data to files.
#
# Prepare Training Data: Combines all cochleagrams and labels from the training set into a format suitable for model training.

# %%
audio_files = audio_data
train_set = {}
test_set = {}

for audio_file in audio_files:
    print(audio_file)
    print(len(audio_files))

    # any(isinstance(i, audio_files) for i in audio_files)
    base_name = audio_file.split(".")[0]
    print(base_name)
    tmp_list = base_name.split("-")
    print(tmp_list)
    emotion = int(tmp_list[3])
    emotion_intensity = tmp_list[4]
    statement = tmp_list[5]
    repetition = tmp_list[6]
    actor = int(tmp_list[7])

    print(f"Processing {audio_file}: Actor {actor}, Emotion {emotion}")

    cochleagram, status = convert_to_cochleagram(
        os.path.join(AUDIO_DIR, audio_file),
        decimation_factor=DECIMATION_FACTOR,
        maxLength=MAX_LENGTH,
    )

    np.save("cochleagram", cochleagram)

    print("cochleagram Shape", cochleagram.shape)

    if cochleagram is None:
        print(f"Failed to convert: {audio_file}")
        continue

    label = to_categorical(emotion - 1, num_classes=NUM_LABELS)
    print("Label", label)

    if actor in train_actors:
        train_set[audio_file] = {"coch": cochleagram, "label": label}
    else:
        test_set[audio_file] = {"coch": cochleagram, "label": label}


X_train = None
y_train = None
for file_name in train_set.keys():

    coch = train_set[file_name]["coch"]

    if X_train is None:
        X_train = coch
    else:
        X_train = np.concatenate([X_train, coch])

    label = train_set[file_name]["label"] * 2 - 1
    labels = np.repeat(label.reshape(-1, 1), coch.shape[0], axis=1).T

    if y_train is None:
        y_train = labels
    else:
        y_train = np.concatenate([y_train, labels])

np.save("train_set", train_set)
np.save("test_set", test_set)
# Out:
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-02-02-01-01-02.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-02-02-01-01-02
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_02/03', '01', '02', '02', '01', '01', '02']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-02-02-01-01-02.wav: Actor 2, Emotion 2
# cochleagram Shape (243, 77)
# Label [0. 1. 0. 0. 0. 0. 0. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-01-01-01-02-02.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-01-01-01-02-02
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_02/03', '01', '01', '01', '01', '02', '02']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-01-01-01-02-02.wav: Actor 2, Emotion 1
# cochleagram Shape (243, 77)
# Label [1. 0. 0. 0. 0. 0. 0. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-04-02-01-02-02.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-04-02-01-02-02
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_02/03', '01', '04', '02', '01', '02', '02']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-04-02-01-02-02.wav: Actor 2, Emotion 4
# cochleagram Shape (243, 77)
# Label [0. 0. 0. 1. 0. 0. 0. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-05-02-02-01-02.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-05-02-02-01-02
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_02/03', '01', '05', '02', '02', '01', '02']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-05-02-02-01-02.wav: Actor 2, Emotion 5
# cochleagram Shape (243, 77)
# Label [0. 0. 0. 0. 1. 0. 0. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-08-01-02-02-02.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-08-01-02-02-02
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_02/03', '01', '08', '01', '02', '02', '02']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-08-01-02-02-02.wav: Actor 2, Emotion 8
# cochleagram Shape (243, 77)
# Label [0. 0. 0. 0. 0. 0. 0. 1.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-01-01-02-02-02.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-01-01-02-02-02
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_02/03', '01', '01', '01', '02', '02', '02']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-01-01-02-02-02.wav: Actor 2, Emotion 1
# cochleagram Shape (243, 77)
# Label [1. 0. 0. 0. 0. 0. 0. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-05-02-01-01-02.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-05-02-01-01-02
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_02/03', '01', '05', '02', '01', '01', '02']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-05-02-01-01-02.wav: Actor 2, Emotion 5
# cochleagram Shape (243, 77)
# Label [0. 0. 0. 0. 1. 0. 0. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-06-02-02-02-02.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-06-02-02-02-02
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_02/03', '01', '06', '02', '02', '02', '02']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-06-02-02-02-02.wav: Actor 2, Emotion 6
# cochleagram Shape (243, 77)
# Label [0. 0. 0. 0. 0. 1. 0. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-03-01-02-02-02.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-03-01-02-02-02
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_02/03', '01', '03', '01', '02', '02', '02']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-03-01-02-02-02.wav: Actor 2, Emotion 3
# cochleagram Shape (243, 77)
# Label [0. 0. 1. 0. 0. 0. 0. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-04-02-02-01-02.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-04-02-02-01-02
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_02/03', '01', '04', '02', '02', '01', '02']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-04-02-02-01-02.wav: Actor 2, Emotion 4
# cochleagram Shape (243, 77)
# Label [0. 0. 0. 1. 0. 0. 0. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-07-02-02-01-02.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-07-02-02-01-02
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_02/03', '01', '07', '02', '02', '01', '02']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-07-02-02-01-02.wav: Actor 2, Emotion 7
# cochleagram Shape (243, 77)
# Label [0. 0. 0. 0. 0. 0. 1. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-05-01-02-01-02.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-05-01-02-01-02
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_02/03', '01', '05', '01', '02', '01', '02']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-05-01-02-01-02.wav: Actor 2, Emotion 5
# cochleagram Shape (243, 77)
# Label [0. 0. 0. 0. 1. 0. 0. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-07-02-02-02-02.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-07-02-02-02-02
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_02/03', '01', '07', '02', '02', '02', '02']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-07-02-02-02-02.wav: Actor 2, Emotion 7
# cochleagram Shape (243, 77)
# Label [0. 0. 0. 0. 0. 0. 1. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-07-02-01-02-02.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-07-02-01-02-02
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_02/03', '01', '07', '02', '01', '02', '02']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-07-02-01-02-02.wav: Actor 2, Emotion 7
# cochleagram Shape (243, 77)
# Label [0. 0. 0. 0. 0. 0. 1. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-01-01-02-01-02.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-01-01-02-01-02
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_02/03', '01', '01', '01', '02', '01', '02']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-01-01-02-01-02.wav: Actor 2, Emotion 1
# cochleagram Shape (243, 77)
# Label [1. 0. 0. 0. 0. 0. 0. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-05-02-02-02-02.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-05-02-02-02-02
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_02/03', '01', '05', '02', '02', '02', '02']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-05-02-02-02-02.wav: Actor 2, Emotion 5
# cochleagram Shape (243, 77)
# Label [0. 0. 0. 0. 1. 0. 0. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-02-02-02-01-02.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-02-02-02-01-02
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_02/03', '01', '02', '02', '02', '01', '02']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-02-02-02-01-02.wav: Actor 2, Emotion 2
# cochleagram Shape (243, 77)
# Label [0. 1. 0. 0. 0. 0. 0. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-05-01-01-01-02.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-05-01-01-01-02
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_02/03', '01', '05', '01', '01', '01', '02']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-05-01-01-01-02.wav: Actor 2, Emotion 5
# cochleagram Shape (243, 77)
# Label [0. 0. 0. 0. 1. 0. 0. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-03-02-01-02-02.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-03-02-01-02-02
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_02/03', '01', '03', '02', '01', '02', '02']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-03-02-01-02-02.wav: Actor 2, Emotion 3
# cochleagram Shape (243, 77)
# Label [0. 0. 1. 0. 0. 0. 0. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-08-02-01-01-02.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-08-02-01-01-02
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_02/03', '01', '08', '02', '01', '01', '02']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-08-02-01-01-02.wav: Actor 2, Emotion 8
# cochleagram Shape (243, 77)
# Label [0. 0. 0. 0. 0. 0. 0. 1.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-04-01-02-02-02.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-04-01-02-02-02
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_02/03', '01', '04', '01', '02', '02', '02']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-04-01-02-02-02.wav: Actor 2, Emotion 4
# cochleagram Shape (243, 77)
# Label [0. 0. 0. 1. 0. 0. 0. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-02-01-02-01-02.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-02-01-02-01-02
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_02/03', '01', '02', '01', '02', '01', '02']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-02-01-02-01-02.wav: Actor 2, Emotion 2
# cochleagram Shape (243, 77)
# Label [0. 1. 0. 0. 0. 0. 0. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-04-02-02-02-02.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-04-02-02-02-02
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_02/03', '01', '04', '02', '02', '02', '02']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-04-02-02-02-02.wav: Actor 2, Emotion 4
# cochleagram Shape (243, 77)
# Label [0. 0. 0. 1. 0. 0. 0. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-06-01-01-01-02.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-06-01-01-01-02
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_02/03', '01', '06', '01', '01', '01', '02']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-06-01-01-01-02.wav: Actor 2, Emotion 6
# cochleagram Shape (243, 77)
# Label [0. 0. 0. 0. 0. 1. 0. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-03-01-01-01-02.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-03-01-01-01-02
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_02/03', '01', '03', '01', '01', '01', '02']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-03-01-01-01-02.wav: Actor 2, Emotion 3
# cochleagram Shape (243, 77)
# Label [0. 0. 1. 0. 0. 0. 0. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-01-01-01-01-02.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-01-01-01-01-02
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_02/03', '01', '01', '01', '01', '01', '02']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-01-01-01-01-02.wav: Actor 2, Emotion 1
# cochleagram Shape (243, 77)
# Label [1. 0. 0. 0. 0. 0. 0. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-07-02-01-01-02.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-07-02-01-01-02
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_02/03', '01', '07', '02', '01', '01', '02']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-07-02-01-01-02.wav: Actor 2, Emotion 7
# cochleagram Shape (243, 77)
# Label [0. 0. 0. 0. 0. 0. 1. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-06-01-02-01-02.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-06-01-02-01-02
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_02/03', '01', '06', '01', '02', '01', '02']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-06-01-02-01-02.wav: Actor 2, Emotion 6
# cochleagram Shape (243, 77)
# Label [0. 0. 0. 0. 0. 1. 0. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-07-01-01-02-02.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-07-01-01-02-02
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_02/03', '01', '07', '01', '01', '02', '02']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-07-01-01-02-02.wav: Actor 2, Emotion 7
# cochleagram Shape (243, 77)
# Label [0. 0. 0. 0. 0. 0. 1. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-03-01-02-01-02.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-03-01-02-01-02
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_02/03', '01', '03', '01', '02', '01', '02']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-03-01-02-01-02.wav: Actor 2, Emotion 3
# cochleagram Shape (243, 77)
# Label [0. 0. 1. 0. 0. 0. 0. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-07-01-02-02-02.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-07-01-02-02-02
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_02/03', '01', '07', '01', '02', '02', '02']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-07-01-02-02-02.wav: Actor 2, Emotion 7
# cochleagram Shape (243, 77)
# Label [0. 0. 0. 0. 0. 0. 1. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-02-01-02-02-02.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-02-01-02-02-02
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_02/03', '01', '02', '01', '02', '02', '02']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-02-01-02-02-02.wav: Actor 2, Emotion 2
# cochleagram Shape (243, 77)
# Label [0. 1. 0. 0. 0. 0. 0. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-08-01-02-01-02.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-08-01-02-01-02
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_02/03', '01', '08', '01', '02', '01', '02']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-08-01-02-01-02.wav: Actor 2, Emotion 8
# cochleagram Shape (243, 77)
# Label [0. 0. 0. 0. 0. 0. 0. 1.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-02-02-01-02-02.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-02-02-01-02-02
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_02/03', '01', '02', '02', '01', '02', '02']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-02-02-01-02-02.wav: Actor 2, Emotion 2
# cochleagram Shape (243, 77)
# Label [0. 1. 0. 0. 0. 0. 0. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-04-01-01-01-02.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-04-01-01-01-02
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_02/03', '01', '04', '01', '01', '01', '02']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-04-01-01-01-02.wav: Actor 2, Emotion 4
# cochleagram Shape (243, 77)
# Label [0. 0. 0. 1. 0. 0. 0. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-05-01-01-02-02.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-05-01-01-02-02
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_02/03', '01', '05', '01', '01', '02', '02']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-05-01-01-02-02.wav: Actor 2, Emotion 5
# cochleagram Shape (243, 77)
# Label [0. 0. 0. 0. 1. 0. 0. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-05-02-01-02-02.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-05-02-01-02-02
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_02/03', '01', '05', '02', '01', '02', '02']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-05-02-01-02-02.wav: Actor 2, Emotion 5
# cochleagram Shape (243, 77)
# Label [0. 0. 0. 0. 1. 0. 0. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-08-02-02-02-02.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-08-02-02-02-02
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_02/03', '01', '08', '02', '02', '02', '02']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-08-02-02-02-02.wav: Actor 2, Emotion 8
# cochleagram Shape (243, 77)
# Label [0. 0. 0. 0. 0. 0. 0. 1.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-02-01-01-02-02.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-02-01-01-02-02
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_02/03', '01', '02', '01', '01', '02', '02']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-02-01-01-02-02.wav: Actor 2, Emotion 2
# cochleagram Shape (243, 77)
# Label [0. 1. 0. 0. 0. 0. 0. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-06-02-02-01-02.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-06-02-02-01-02
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_02/03', '01', '06', '02', '02', '01', '02']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-06-02-02-01-02.wav: Actor 2, Emotion 6
# cochleagram Shape (243, 77)
# Label [0. 0. 0. 0. 0. 1. 0. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-07-01-02-01-02.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-07-01-02-01-02
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_02/03', '01', '07', '01', '02', '01', '02']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-07-01-02-01-02.wav: Actor 2, Emotion 7
# cochleagram Shape (243, 77)
# Label [0. 0. 0. 0. 0. 0. 1. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-04-01-02-01-02.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-04-01-02-01-02
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_02/03', '01', '04', '01', '02', '01', '02']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-04-01-02-01-02.wav: Actor 2, Emotion 4
# cochleagram Shape (243, 77)
# Label [0. 0. 0. 1. 0. 0. 0. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-06-01-01-02-02.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-06-01-01-02-02
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_02/03', '01', '06', '01', '01', '02', '02']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-06-01-01-02-02.wav: Actor 2, Emotion 6
# cochleagram Shape (243, 77)
# Label [0. 0. 0. 0. 0. 1. 0. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-06-01-02-02-02.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-06-01-02-02-02
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_02/03', '01', '06', '01', '02', '02', '02']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-06-01-02-02-02.wav: Actor 2, Emotion 6
# cochleagram Shape (243, 77)
# Label [0. 0. 0. 0. 0. 1. 0. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-04-02-01-01-02.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-04-02-01-01-02
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_02/03', '01', '04', '02', '01', '01', '02']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-04-02-01-01-02.wav: Actor 2, Emotion 4
# cochleagram Shape (243, 77)
# Label [0. 0. 0. 1. 0. 0. 0. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-05-01-02-02-02.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-05-01-02-02-02
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_02/03', '01', '05', '01', '02', '02', '02']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-05-01-02-02-02.wav: Actor 2, Emotion 5
# cochleagram Shape (243, 77)
# Label [0. 0. 0. 0. 1. 0. 0. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-02-01-01-01-02.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-02-01-01-01-02
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_02/03', '01', '02', '01', '01', '01', '02']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-02-01-01-01-02.wav: Actor 2, Emotion 2
# cochleagram Shape (243, 77)
# Label [0. 1. 0. 0. 0. 0. 0. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-06-02-01-02-02.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-06-02-01-02-02
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_02/03', '01', '06', '02', '01', '02', '02']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-06-02-01-02-02.wav: Actor 2, Emotion 6
# cochleagram Shape (243, 77)
# Label [0. 0. 0. 0. 0. 1. 0. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-06-02-01-01-02.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-06-02-01-01-02
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_02/03', '01', '06', '02', '01', '01', '02']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-06-02-01-01-02.wav: Actor 2, Emotion 6
# cochleagram Shape (243, 77)
# Label [0. 0. 0. 0. 0. 1. 0. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-08-02-02-01-02.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-08-02-02-01-02
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_02/03', '01', '08', '02', '02', '01', '02']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-08-02-02-01-02.wav: Actor 2, Emotion 8
# cochleagram Shape (243, 77)
# Label [0. 0. 0. 0. 0. 0. 0. 1.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-03-01-01-02-02.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-03-01-01-02-02
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_02/03', '01', '03', '01', '01', '02', '02']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-03-01-01-02-02.wav: Actor 2, Emotion 3
# cochleagram Shape (243, 77)
# Label [0. 0. 1. 0. 0. 0. 0. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-08-01-01-01-02.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-08-01-01-01-02
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_02/03', '01', '08', '01', '01', '01', '02']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-08-01-01-01-02.wav: Actor 2, Emotion 8
# cochleagram Shape (243, 77)
# Label [0. 0. 0. 0. 0. 0. 0. 1.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-08-02-01-02-02.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-08-02-01-02-02
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_02/03', '01', '08', '02', '01', '02', '02']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-08-02-01-02-02.wav: Actor 2, Emotion 8
# cochleagram Shape (243, 77)
# Label [0. 0. 0. 0. 0. 0. 0. 1.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-07-01-01-01-02.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-07-01-01-01-02
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_02/03', '01', '07', '01', '01', '01', '02']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-07-01-01-01-02.wav: Actor 2, Emotion 7
# cochleagram Shape (243, 77)
# Label [0. 0. 0. 0. 0. 0. 1. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-03-02-02-02-02.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-03-02-02-02-02
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_02/03', '01', '03', '02', '02', '02', '02']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-03-02-02-02-02.wav: Actor 2, Emotion 3
# cochleagram Shape (243, 77)
# Label [0. 0. 1. 0. 0. 0. 0. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-08-01-01-02-02.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-08-01-01-02-02
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_02/03', '01', '08', '01', '01', '02', '02']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-08-01-01-02-02.wav: Actor 2, Emotion 8
# cochleagram Shape (243, 77)
# Label [0. 0. 0. 0. 0. 0. 0. 1.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-03-02-01-01-02.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-03-02-01-01-02
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_02/03', '01', '03', '02', '01', '01', '02']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-03-02-01-01-02.wav: Actor 2, Emotion 3
# cochleagram Shape (243, 77)
# Label [0. 0. 1. 0. 0. 0. 0. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-03-02-02-01-02.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-03-02-02-01-02
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_02/03', '01', '03', '02', '02', '01', '02']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-03-02-02-01-02.wav: Actor 2, Emotion 3
# cochleagram Shape (243, 77)
# Label [0. 0. 1. 0. 0. 0. 0. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-02-02-02-02-02.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-02-02-02-02-02
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_02/03', '01', '02', '02', '02', '02', '02']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-02-02-02-02-02.wav: Actor 2, Emotion 2
# cochleagram Shape (243, 77)
# Label [0. 1. 0. 0. 0. 0. 0. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-04-01-01-02-02.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-04-01-01-02-02
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_02/03', '01', '04', '01', '01', '02', '02']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_02/03-01-04-01-01-02-02.wav: Actor 2, Emotion 4
# cochleagram Shape (243, 77)
# Label [0. 0. 0. 1. 0. 0. 0. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-03-02-01-01-22.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-03-02-01-01-22
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_22/03', '01', '03', '02', '01', '01', '22']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-03-02-01-01-22.wav: Actor 22, Emotion 3
# cochleagram Shape (243, 77)
# Label [0. 0. 1. 0. 0. 0. 0. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-06-01-01-01-22.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-06-01-01-01-22
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_22/03', '01', '06', '01', '01', '01', '22']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-06-01-01-01-22.wav: Actor 22, Emotion 6
# cochleagram Shape (243, 77)
# Label [0. 0. 0. 0. 0. 1. 0. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-05-01-02-01-22.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-05-01-02-01-22
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_22/03', '01', '05', '01', '02', '01', '22']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-05-01-02-01-22.wav: Actor 22, Emotion 5
# cochleagram Shape (243, 77)
# Label [0. 0. 0. 0. 1. 0. 0. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-05-01-02-02-22.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-05-01-02-02-22
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_22/03', '01', '05', '01', '02', '02', '22']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-05-01-02-02-22.wav: Actor 22, Emotion 5
# cochleagram Shape (243, 77)
# Label [0. 0. 0. 0. 1. 0. 0. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-02-01-01-02-22.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-02-01-01-02-22
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_22/03', '01', '02', '01', '01', '02', '22']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-02-01-01-02-22.wav: Actor 22, Emotion 2
# cochleagram Shape (243, 77)
# Label [0. 1. 0. 0. 0. 0. 0. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-08-02-02-02-22.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-08-02-02-02-22
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_22/03', '01', '08', '02', '02', '02', '22']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-08-02-02-02-22.wav: Actor 22, Emotion 8
# cochleagram Shape (243, 77)
# Label [0. 0. 0. 0. 0. 0. 0. 1.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-01-01-02-02-22.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-01-01-02-02-22
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_22/03', '01', '01', '01', '02', '02', '22']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-01-01-02-02-22.wav: Actor 22, Emotion 1
# cochleagram Shape (243, 77)
# Label [1. 0. 0. 0. 0. 0. 0. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-05-01-01-02-22.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-05-01-01-02-22
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_22/03', '01', '05', '01', '01', '02', '22']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-05-01-01-02-22.wav: Actor 22, Emotion 5
# cochleagram Shape (243, 77)
# Label [0. 0. 0. 0. 1. 0. 0. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-04-01-02-01-22.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-04-01-02-01-22
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_22/03', '01', '04', '01', '02', '01', '22']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-04-01-02-01-22.wav: Actor 22, Emotion 4
# cochleagram Shape (243, 77)
# Label [0. 0. 0. 1. 0. 0. 0. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-07-01-02-02-22.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-07-01-02-02-22
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_22/03', '01', '07', '01', '02', '02', '22']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-07-01-02-02-22.wav: Actor 22, Emotion 7
# cochleagram Shape (243, 77)
# Label [0. 0. 0. 0. 0. 0. 1. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-02-02-01-01-22.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-02-02-01-01-22
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_22/03', '01', '02', '02', '01', '01', '22']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-02-02-01-01-22.wav: Actor 22, Emotion 2
# cochleagram Shape (243, 77)
# Label [0. 1. 0. 0. 0. 0. 0. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-01-01-02-01-22.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-01-01-02-01-22
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_22/03', '01', '01', '01', '02', '01', '22']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-01-01-02-01-22.wav: Actor 22, Emotion 1
# cochleagram Shape (243, 77)
# Label [1. 0. 0. 0. 0. 0. 0. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-07-02-01-02-22.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-07-02-01-02-22
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_22/03', '01', '07', '02', '01', '02', '22']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-07-02-01-02-22.wav: Actor 22, Emotion 7
# cochleagram Shape (243, 77)
# Label [0. 0. 0. 0. 0. 0. 1. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-02-02-01-02-22.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-02-02-01-02-22
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_22/03', '01', '02', '02', '01', '02', '22']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-02-02-01-02-22.wav: Actor 22, Emotion 2
# cochleagram Shape (243, 77)
# Label [0. 1. 0. 0. 0. 0. 0. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-05-02-02-02-22.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-05-02-02-02-22
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_22/03', '01', '05', '02', '02', '02', '22']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-05-02-02-02-22.wav: Actor 22, Emotion 5
# cochleagram Shape (243, 77)
# Label [0. 0. 0. 0. 1. 0. 0. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-07-02-01-01-22.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-07-02-01-01-22
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_22/03', '01', '07', '02', '01', '01', '22']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-07-02-01-01-22.wav: Actor 22, Emotion 7
# cochleagram Shape (243, 77)
# Label [0. 0. 0. 0. 0. 0. 1. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-06-02-01-01-22.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-06-02-01-01-22
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_22/03', '01', '06', '02', '01', '01', '22']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-06-02-01-01-22.wav: Actor 22, Emotion 6
# cochleagram Shape (243, 77)
# Label [0. 0. 0. 0. 0. 1. 0. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-03-01-01-02-22.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-03-01-01-02-22
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_22/03', '01', '03', '01', '01', '02', '22']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-03-01-01-02-22.wav: Actor 22, Emotion 3
# cochleagram Shape (243, 77)
# Label [0. 0. 1. 0. 0. 0. 0. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-04-01-01-01-22.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-04-01-01-01-22
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_22/03', '01', '04', '01', '01', '01', '22']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-04-01-01-01-22.wav: Actor 22, Emotion 4
# cochleagram Shape (243, 77)
# Label [0. 0. 0. 1. 0. 0. 0. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-02-01-01-01-22.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-02-01-01-01-22
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_22/03', '01', '02', '01', '01', '01', '22']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-02-01-01-01-22.wav: Actor 22, Emotion 2
# cochleagram Shape (243, 77)
# Label [0. 1. 0. 0. 0. 0. 0. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-03-01-02-01-22.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-03-01-02-01-22
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_22/03', '01', '03', '01', '02', '01', '22']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-03-01-02-01-22.wav: Actor 22, Emotion 3
# cochleagram Shape (243, 77)
# Label [0. 0. 1. 0. 0. 0. 0. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-02-02-02-02-22.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-02-02-02-02-22
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_22/03', '01', '02', '02', '02', '02', '22']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-02-02-02-02-22.wav: Actor 22, Emotion 2
# cochleagram Shape (243, 77)
# Label [0. 1. 0. 0. 0. 0. 0. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-06-01-01-02-22.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-06-01-01-02-22
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_22/03', '01', '06', '01', '01', '02', '22']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-06-01-01-02-22.wav: Actor 22, Emotion 6
# cochleagram Shape (243, 77)
# Label [0. 0. 0. 0. 0. 1. 0. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-07-01-01-01-22.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-07-01-01-01-22
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_22/03', '01', '07', '01', '01', '01', '22']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-07-01-01-01-22.wav: Actor 22, Emotion 7
# cochleagram Shape (243, 77)
# Label [0. 0. 0. 0. 0. 0. 1. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-06-01-02-02-22.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-06-01-02-02-22
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_22/03', '01', '06', '01', '02', '02', '22']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-06-01-02-02-22.wav: Actor 22, Emotion 6
# cochleagram Shape (243, 77)
# Label [0. 0. 0. 0. 0. 1. 0. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-08-01-01-02-22.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-08-01-01-02-22
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_22/03', '01', '08', '01', '01', '02', '22']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-08-01-01-02-22.wav: Actor 22, Emotion 8
# cochleagram Shape (243, 77)
# Label [0. 0. 0. 0. 0. 0. 0. 1.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-05-02-01-02-22.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-05-02-01-02-22
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_22/03', '01', '05', '02', '01', '02', '22']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-05-02-01-02-22.wav: Actor 22, Emotion 5
# cochleagram Shape (243, 77)
# Label [0. 0. 0. 0. 1. 0. 0. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-04-02-02-02-22.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-04-02-02-02-22
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_22/03', '01', '04', '02', '02', '02', '22']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-04-02-02-02-22.wav: Actor 22, Emotion 4
# cochleagram Shape (243, 77)
# Label [0. 0. 0. 1. 0. 0. 0. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-08-02-01-01-22.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-08-02-01-01-22
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_22/03', '01', '08', '02', '01', '01', '22']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-08-02-01-01-22.wav: Actor 22, Emotion 8
# cochleagram Shape (243, 77)
# Label [0. 0. 0. 0. 0. 0. 0. 1.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-01-01-01-01-22.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-01-01-01-01-22
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_22/03', '01', '01', '01', '01', '01', '22']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-01-01-01-01-22.wav: Actor 22, Emotion 1
# cochleagram Shape (243, 77)
# Label [1. 0. 0. 0. 0. 0. 0. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-07-02-02-01-22.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-07-02-02-01-22
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_22/03', '01', '07', '02', '02', '01', '22']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-07-02-02-01-22.wav: Actor 22, Emotion 7
# cochleagram Shape (243, 77)
# Label [0. 0. 0. 0. 0. 0. 1. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-04-02-02-01-22.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-04-02-02-01-22
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_22/03', '01', '04', '02', '02', '01', '22']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-04-02-02-01-22.wav: Actor 22, Emotion 4
# cochleagram Shape (243, 77)
# Label [0. 0. 0. 1. 0. 0. 0. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-03-02-02-01-22.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-03-02-02-01-22
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_22/03', '01', '03', '02', '02', '01', '22']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-03-02-02-01-22.wav: Actor 22, Emotion 3
# cochleagram Shape (243, 77)
# Label [0. 0. 1. 0. 0. 0. 0. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-06-02-02-01-22.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-06-02-02-01-22
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_22/03', '01', '06', '02', '02', '01', '22']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-06-02-02-01-22.wav: Actor 22, Emotion 6
# cochleagram Shape (243, 77)
# Label [0. 0. 0. 0. 0. 1. 0. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-07-02-02-02-22.wav
# 1440
# ...
# cochleagram Shape (243, 77)
# Label [0. 1. 0. 0. 0. 0. 0. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_12/03-01-04-02-02-02-12.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_12/03-01-04-02-02-02-12
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_12/03', '01', '04', '02', '02', '02', '12']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_12/03-01-04-02-02-02-12.wav: Actor 12, Emotion 4
# cochleagram Shape (243, 77)
# Label [0. 0. 0. 1. 0. 0. 0. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_12/03-01-07-02-01-01-12.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_12/03-01-07-02-01-01-12
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_12/03', '01', '07', '02', '01', '01', '12']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_12/03-01-07-02-01-01-12.wav: Actor 12, Emotion 7
# cochleagram Shape (243, 77)
# Label [0. 0. 0. 0. 0. 0. 1. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_12/03-01-08-02-01-01-12.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_12/03-01-08-02-01-01-12
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_12/03', '01', '08', '02', '01', '01', '12']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_12/03-01-08-02-01-01-12.wav: Actor 12, Emotion 8
# cochleagram Shape (243, 77)
# Label [0. 0. 0. 0. 0. 0. 0. 1.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_12/03-01-08-02-02-01-12.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_12/03-01-08-02-02-01-12
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_12/03', '01', '08', '02', '02', '01', '12']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_12/03-01-08-02-02-01-12.wav: Actor 12, Emotion 8
# cochleagram Shape (243, 77)
# Label [0. 0. 0. 0. 0. 0. 0. 1.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_12/03-01-04-01-02-02-12.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_12/03-01-04-01-02-02-12
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_12/03', '01', '04', '01', '02', '02', '12']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_12/03-01-04-01-02-02-12.wav: Actor 12, Emotion 4
# cochleagram Shape (243, 77)
# Label [0. 0. 0. 1. 0. 0. 0. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_12/03-01-06-01-01-02-12.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_12/03-01-06-01-01-02-12
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_12/03', '01', '06', '01', '01', '02', '12']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_12/03-01-06-01-01-02-12.wav: Actor 12, Emotion 6
# cochleagram Shape (243, 77)
# Label [0. 0. 0. 0. 0. 1. 0. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_12/03-01-04-01-01-01-12.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_12/03-01-04-01-01-01-12
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_12/03', '01', '04', '01', '01', '01', '12']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_12/03-01-04-01-01-01-12.wav: Actor 12, Emotion 4
# cochleagram Shape (243, 77)
# Label [0. 0. 0. 1. 0. 0. 0. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_12/03-01-05-02-02-01-12.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_12/03-01-05-02-02-01-12
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_12/03', '01', '05', '02', '02', '01', '12']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_12/03-01-05-02-02-01-12.wav: Actor 12, Emotion 5
# cochleagram Shape (243, 77)
# Label [0. 0. 0. 0. 1. 0. 0. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_12/03-01-06-01-02-01-12.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_12/03-01-06-01-02-01-12
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_12/03', '01', '06', '01', '02', '01', '12']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_12/03-01-06-01-02-01-12.wav: Actor 12, Emotion 6
# cochleagram Shape (243, 77)
# Label [0. 0. 0. 0. 0. 1. 0. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_12/03-01-04-01-01-02-12.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_12/03-01-04-01-01-02-12
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_12/03', '01', '04', '01', '01', '02', '12']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_12/03-01-04-01-01-02-12.wav: Actor 12, Emotion 4
# cochleagram Shape (243, 77)
# Label [0. 0. 0. 1. 0. 0. 0. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_12/03-01-01-01-02-01-12.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_12/03-01-01-01-02-01-12
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_12/03', '01', '01', '01', '02', '01', '12']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_12/03-01-01-01-02-01-12.wav: Actor 12, Emotion 1
# cochleagram Shape (243, 77)
# Label [1. 0. 0. 0. 0. 0. 0. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_12/03-01-04-02-01-02-12.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_12/03-01-04-02-01-02-12
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_12/03', '01', '04', '02', '01', '02', '12']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_12/03-01-04-02-01-02-12.wav: Actor 12, Emotion 4
# cochleagram Shape (243, 77)
# Label [0. 0. 0. 1. 0. 0. 0. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_12/03-01-05-01-02-01-12.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_12/03-01-05-01-02-01-12
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_12/03', '01', '05', '01', '02', '01', '12']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_12/03-01-05-01-02-01-12.wav: Actor 12, Emotion 5
# cochleagram Shape (243, 77)
# Label [0. 0. 0. 0. 1. 0. 0. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_12/03-01-05-02-02-02-12.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_12/03-01-05-02-02-02-12
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_12/03', '01', '05', '02', '02', '02', '12']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_12/03-01-05-02-02-02-12.wav: Actor 12, Emotion 5
# cochleagram Shape (243, 77)
# Label [0. 0. 0. 0. 1. 0. 0. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_12/03-01-06-02-02-01-12.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_12/03-01-06-02-02-01-12
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_12/03', '01', '06', '02', '02', '01', '12']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_12/03-01-06-02-02-01-12.wav: Actor 12, Emotion 6
# cochleagram Shape (243, 77)
# Label [0. 0. 0. 0. 0. 1. 0. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_12/03-01-02-01-01-01-12.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_12/03-01-02-01-01-01-12
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_12/03', '01', '02', '01', '01', '01', '12']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_12/03-01-02-01-01-01-12.wav: Actor 12, Emotion 2
# cochleagram Shape (243, 77)
# Label [0. 1. 0. 0. 0. 0. 0. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_12/03-01-06-02-02-02-12.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_12/03-01-06-02-02-02-12
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_12/03', '01', '06', '02', '02', '02', '12']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_12/03-01-06-02-02-02-12.wav: Actor 12, Emotion 6
# cochleagram Shape (243, 77)
# Label [0. 0. 0. 0. 0. 1. 0. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_12/03-01-06-01-01-01-12.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_12/03-01-06-01-01-01-12
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_12/03', '01', '06', '01', '01', '01', '12']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_12/03-01-06-01-01-01-12.wav: Actor 12, Emotion 6
# cochleagram Shape (243, 77)
# Label [0. 0. 0. 0. 0. 1. 0. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_12/03-01-06-01-02-02-12.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_12/03-01-06-01-02-02-12
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_12/03', '01', '06', '01', '02', '02', '12']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_12/03-01-06-01-02-02-12.wav: Actor 12, Emotion 6
# cochleagram Shape (243, 77)
# Label [0. 0. 0. 0. 0. 1. 0. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_12/03-01-03-01-01-01-12.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_12/03-01-03-01-01-01-12
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_12/03', '01', '03', '01', '01', '01', '12']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_12/03-01-03-01-01-01-12.wav: Actor 12, Emotion 3
# cochleagram Shape (243, 77)
# Label [0. 0. 1. 0. 0. 0. 0. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_12/03-01-04-02-01-01-12.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_12/03-01-04-02-01-01-12
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_12/03', '01', '04', '02', '01', '01', '12']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_12/03-01-04-02-01-01-12.wav: Actor 12, Emotion 4
# cochleagram Shape (243, 77)
# Label [0. 0. 0. 1. 0. 0. 0. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_12/03-01-05-01-01-01-12.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_12/03-01-05-01-01-01-12
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_12/03', '01', '05', '01', '01', '01', '12']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_12/03-01-05-01-01-01-12.wav: Actor 12, Emotion 5
# cochleagram Shape (243, 77)
# Label [0. 0. 0. 0. 1. 0. 0. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_12/03-01-02-02-02-01-12.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_12/03-01-02-02-02-01-12
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_12/03', '01', '02', '02', '02', '01', '12']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_12/03-01-02-02-02-01-12.wav: Actor 12, Emotion 2
# cochleagram Shape (243, 77)
# Label [0. 1. 0. 0. 0. 0. 0. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_12/03-01-02-01-01-02-12.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_12/03-01-02-01-01-02-12
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_12/03', '01', '02', '01', '01', '02', '12']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_12/03-01-02-01-01-02-12.wav: Actor 12, Emotion 2
# cochleagram Shape (243, 77)
# Label [0. 1. 0. 0. 0. 0. 0. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_12/03-01-08-01-02-01-12.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_12/03-01-08-01-02-01-12
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_12/03', '01', '08', '01', '02', '01', '12']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_12/03-01-08-01-02-01-12.wav: Actor 12, Emotion 8
# cochleagram Shape (243, 77)
# Label [0. 0. 0. 0. 0. 0. 0. 1.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_12/03-01-03-01-01-02-12.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_12/03-01-03-01-01-02-12
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_12/03', '01', '03', '01', '01', '02', '12']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_12/03-01-03-01-01-02-12.wav: Actor 12, Emotion 3
# cochleagram Shape (243, 77)
# Label [0. 0. 1. 0. 0. 0. 0. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_12/03-01-08-02-01-02-12.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_12/03-01-08-02-01-02-12
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_12/03', '01', '08', '02', '01', '02', '12']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_12/03-01-08-02-01-02-12.wav: Actor 12, Emotion 8
# cochleagram Shape (243, 77)
# Label [0. 0. 0. 0. 0. 0. 0. 1.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_12/03-01-06-02-01-01-12.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_12/03-01-06-02-01-01-12
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_12/03', '01', '06', '02', '01', '01', '12']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_12/03-01-06-02-01-01-12.wav: Actor 12, Emotion 6
# cochleagram Shape (243, 77)
# Label [0. 0. 0. 0. 0. 1. 0. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_12/03-01-07-01-02-01-12.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_12/03-01-07-01-02-01-12
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_12/03', '01', '07', '01', '02', '01', '12']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_12/03-01-07-01-02-01-12.wav: Actor 12, Emotion 7
# cochleagram Shape (243, 77)
# Label [0. 0. 0. 0. 0. 0. 1. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_12/03-01-03-01-02-01-12.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_12/03-01-03-01-02-01-12
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_12/03', '01', '03', '01', '02', '01', '12']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_12/03-01-03-01-02-01-12.wav: Actor 12, Emotion 3
# cochleagram Shape (243, 77)
# Label [0. 0. 1. 0. 0. 0. 0. 0.]
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_12/03-01-04-01-02-01-12.wav
# 1440
# /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_12/03-01-04-01-02-01-12
# ['/home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01', '24/Actor_12/03', '01', '04', '01', '02', '01', '12']
# Processing /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_12/03-01-04-01-02-01-12.wav: Actor 12, Emotion 4
# cochleagram Shape (243, 77)
# Label [0. 0. 0. 1. 0. 0. 0. 0.]

# %% [markdown]
# <h2>Connecting to EmuCore</h2>
#
# Import Libraries: Bring in libraries needed for file handling, numerical operations, and interacting with the EmuCore system.
#
# Define Parameters: Set up various parameters required to configure and use the EmuCore reservoir computing system.
#
# Create Client: Create a connection to the EmuCore system using its IP address.
#
# Get System Ready: Wait for the EmuCore system to be ready and get a lock to make changes.
#
# Reset and Configure Reservoir: Reset the reservoir to its initial state and configure it with the defined parameters.
#
# Load Data: Load previously saved training and testing data from files.
#
# Process Training Data: For each training data file:
#
# Check if the number of features matches the expected number.
# Process the data through the reservoir.
# Update the training data with the processed results.
# Verify that the number of features in the output data is correct.
# Process Testing Data: Similarly, process the testing data and update it.
#
# Save Processed Data: Save the processed training and testing data to new files for future use.

# %%
# Import necessary libraries for handling files and numerical operations
import os
import numpy as np
from emucore_direct.client import EmuCoreClient

# Define parameters for the reservoir computing system
IP_ADDR = "172.18.41.60"  # IP address of the EmuCore system
VBIAS = 0.3  # Voltage bias for the reservoir
GAIN = 0.65  # Gain setting for the reservoir
NUM_NODES = 800  # Number of nodes in the reservoir
NUM_TAPS = NUM_NODES  # Number of taps in the reservoir (same as number of nodes)
FEATURE_SCALING = 0.5  # Scaling factor for the features
DENSITY = 1  # Density of connections in the reservoir

NUM_F = 77  # Number of features in the input data

# Create a client to interact with the EmuCore system
client = EmuCoreClient(ip_addr=IP_ADDR)

# Wait for the system to be ready and get a lock
lock_id, start, end = client.wait_for_lock()

# Reset the reservoir to its initial state
client.reservoir_reset(lock_id=lock_id)

# Configure the reservoir with the specified settings
client.rc_config(
    lock_id=lock_id, vbias=VBIAS, gain=GAIN, num_nodes=NUM_NODES, num_taps=NUM_TAPS
)

# Load the training and testing data from saved files
train_set = np.load("train_set.npy", allow_pickle=True).item()
test_set = np.load("test_set.npy", allow_pickle=True).item()

# Process the training data using the reservoir computing system
for item in train_set.keys():
    print("Train", item)  # Print the current training file being processed

    # Ensure that the number of features in the input data matches the expected number
    assert train_set[item]["coch"].shape[1] == NUM_F

    # Process the data through the reservoir
    X_trans_response, _, _ = client.process_all_data(
        input_data=train_set[item]["coch"],
        num_nodes=NUM_NODES,
        density=DENSITY,
        feature_scaling=FEATURE_SCALING,
        lock_id=lock_id,
    )

    # Update the training data with the processed results
    train_set[item]["coch"] = X_trans_response

    # Ensure the number of features in the output data matches the number of nodes
    assert train_set[item]["coch"].shape[1] == NUM_NODES

# Process the testing data in the same way
for item in test_set.keys():
    print("Test", item)  # Print the current testing file being processed

    # Ensure that the number of features in the input data matches the expected number
    assert test_set[item]["coch"].shape[1] == NUM_F

    # Process the data through the reservoir
    X_trans_response, _, _ = client.process_all_data(
        input_data=test_set[item]["coch"],
        num_nodes=NUM_NODES,
        density=DENSITY,
        feature_scaling=FEATURE_SCALING,
        lock_id=lock_id,
    )

    # Update the testing data with the processed results
    test_set[item]["coch"] = X_trans_response

    # Ensure the number of features in the output data matches the number of nodes
    assert test_set[item]["coch"].shape[1] == NUM_NODES

# Save the processed training and testing data to new files
np.save("train_set_ravdess_reservoir2.npy", train_set)
np.save("test_set_ravdess_reservoir2.npy", test_set)
# Out:
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-03-02-01-01-22.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-06-01-01-01-22.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-05-01-02-01-22.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-05-01-02-02-22.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-02-01-01-02-22.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-08-02-02-02-22.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-01-01-02-02-22.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-05-01-01-02-22.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-04-01-02-01-22.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-07-01-02-02-22.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-02-02-01-01-22.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-01-01-02-01-22.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-07-02-01-02-22.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-02-02-01-02-22.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-05-02-02-02-22.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-07-02-01-01-22.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-06-02-01-01-22.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-03-01-01-02-22.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-04-01-01-01-22.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-02-01-01-01-22.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-03-01-02-01-22.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-02-02-02-02-22.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-06-01-01-02-22.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-07-01-01-01-22.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-06-01-02-02-22.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-08-01-01-02-22.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-05-02-01-02-22.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-04-02-02-02-22.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-08-02-01-01-22.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-01-01-01-01-22.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-07-02-02-01-22.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-04-02-02-01-22.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-03-02-02-01-22.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-06-02-02-01-22.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-07-02-02-02-22.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-03-01-01-01-22.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-04-01-01-02-22.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-08-01-01-01-22.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-03-02-01-02-22.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-08-01-02-02-22.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-02-01-02-01-22.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-06-02-01-02-22.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-08-02-02-01-22.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-07-01-02-01-22.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-05-02-01-01-22.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-07-01-01-02-22.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-06-01-02-01-22.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-08-02-01-02-22.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-04-02-01-01-22.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-04-01-02-02-22.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-02-01-02-02-22.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-04-02-01-02-22.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-02-02-02-01-22.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-01-01-01-02-22.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-05-01-01-01-22.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-08-01-02-01-22.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-06-02-02-02-22.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-03-01-02-02-22.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-03-02-02-02-22.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_22/03-01-05-02-02-01-22.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_24/03-01-07-01-02-01-24.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_24/03-01-04-01-02-02-24.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_24/03-01-06-01-01-01-24.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_24/03-01-03-01-01-02-24.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_24/03-01-02-01-01-01-24.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_24/03-01-02-02-01-01-24.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_24/03-01-08-01-01-01-24.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_24/03-01-01-01-01-01-24.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_24/03-01-03-01-02-01-24.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_24/03-01-07-01-02-02-24.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_24/03-01-03-02-02-01-24.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_24/03-01-01-01-02-02-24.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_24/03-01-04-01-02-01-24.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_24/03-01-06-01-02-01-24.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_24/03-01-03-01-01-01-24.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_24/03-01-04-02-02-01-24.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_24/03-01-07-01-01-02-24.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_24/03-01-04-01-01-02-24.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_24/03-01-02-01-02-01-24.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_24/03-01-08-02-02-02-24.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_24/03-01-07-02-02-02-24.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_24/03-01-05-01-01-01-24.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_24/03-01-08-01-02-02-24.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_24/03-01-05-02-01-02-24.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_24/03-01-03-02-02-02-24.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_24/03-01-02-02-01-02-24.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_24/03-01-08-01-02-01-24.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_24/03-01-07-02-02-01-24.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_24/03-01-06-02-01-02-24.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_24/03-01-08-01-01-02-24.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_24/03-01-08-02-01-02-24.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_24/03-01-04-02-01-02-24.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_24/03-01-04-02-01-01-24.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_24/03-01-05-01-02-02-24.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_24/03-01-02-02-02-01-24.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_24/03-01-06-01-02-02-24.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_24/03-01-04-01-01-01-24.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_24/03-01-05-01-01-02-24.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_24/03-01-08-02-02-01-24.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_24/03-01-03-01-02-02-24.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_24/03-01-07-02-01-01-24.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_24/03-01-02-01-01-02-24.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_24/03-01-05-02-01-01-24.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_24/03-01-06-02-02-01-24.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_24/03-01-05-02-02-02-24.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_24/03-01-05-01-02-01-24.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_24/03-01-04-02-02-02-24.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_24/03-01-01-01-02-01-24.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_24/03-01-07-01-01-01-24.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_24/03-01-07-02-01-02-24.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_24/03-01-06-02-02-02-24.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_24/03-01-03-02-01-02-24.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_24/03-01-03-02-01-01-24.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_24/03-01-08-02-01-01-24.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_24/03-01-01-01-01-02-24.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_24/03-01-02-02-02-02-24.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_24/03-01-06-02-01-01-24.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_24/03-01-05-02-02-01-24.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_24/03-01-02-01-02-02-24.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_24/03-01-06-01-01-02-24.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_16/03-01-02-01-01-02-16.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_16/03-01-07-01-02-02-16.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_16/03-01-03-01-01-02-16.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_16/03-01-07-01-01-01-16.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_16/03-01-03-02-02-01-16.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_16/03-01-08-02-01-01-16.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_16/03-01-06-02-02-01-16.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_16/03-01-01-01-02-02-16.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_16/03-01-03-01-02-01-16.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_16/03-01-04-02-01-01-16.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_16/03-01-04-01-01-01-16.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_16/03-01-02-02-01-01-16.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_16/03-01-04-01-02-01-16.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_16/03-01-03-01-01-01-16.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_16/03-01-07-02-01-01-16.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_16/03-01-06-01-02-02-16.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_16/03-01-05-01-01-01-16.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_16/03-01-07-02-02-02-16.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_16/03-01-07-02-02-01-16.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_16/03-01-02-01-01-01-16.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_16/03-01-08-01-02-02-16.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_16/03-01-05-02-01-01-16.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_16/03-01-05-01-02-01-16.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_16/03-01-06-01-02-01-16.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_16/03-01-03-02-02-02-16.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_16/03-01-05-02-02-01-16.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_16/03-01-06-01-01-01-16.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_16/03-01-04-02-01-02-16.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_16/03-01-03-02-01-01-16.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_16/03-01-04-02-02-02-16.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_16/03-01-05-01-01-02-16.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_16/03-01-01-01-02-01-16.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_16/03-01-05-01-02-02-16.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_16/03-01-02-02-01-02-16.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_16/03-01-07-01-01-02-16.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_16/03-01-08-02-02-02-16.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_16/03-01-05-02-02-02-16.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_16/03-01-01-01-01-01-16.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_16/03-01-07-01-02-01-16.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_16/03-01-04-02-02-01-16.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_16/03-01-06-02-01-01-16.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_16/03-01-02-01-02-01-16.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_16/03-01-08-02-02-01-16.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_16/03-01-06-02-01-02-16.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_16/03-01-02-02-02-01-16.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_16/03-01-08-01-02-01-16.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_16/03-01-06-01-01-02-16.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_16/03-01-01-01-01-02-16.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_16/03-01-08-01-01-02-16.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_16/03-01-07-02-01-02-16.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_16/03-01-03-02-01-02-16.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_16/03-01-04-01-02-02-16.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_16/03-01-05-02-01-02-16.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_16/03-01-04-01-01-02-16.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_16/03-01-08-01-01-01-16.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_16/03-01-03-01-02-02-16.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_16/03-01-08-02-01-02-16.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_16/03-01-06-02-02-02-16.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_16/03-01-02-01-02-02-16.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_16/03-01-02-02-02-02-16.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_17/03-01-05-02-01-02-17.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_17/03-01-07-01-02-01-17.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_17/03-01-07-02-01-01-17.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_17/03-01-05-01-02-02-17.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_17/03-01-05-01-01-02-17.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_17/03-01-07-01-01-01-17.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_17/03-01-08-01-02-01-17.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_17/03-01-02-02-02-02-17.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_17/03-01-05-01-02-01-17.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_17/03-01-04-01-01-01-17.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_17/03-01-03-01-01-02-17.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_17/03-01-06-01-02-02-17.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_17/03-01-07-02-02-01-17.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_17/03-01-03-02-02-02-17.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_17/03-01-07-01-01-02-17.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_17/03-01-07-02-02-02-17.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_17/03-01-02-02-01-01-17.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_17/03-01-02-02-02-01-17.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_17/03-01-06-02-02-01-17.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_17/03-01-06-01-01-01-17.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_17/03-01-07-02-01-02-17.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_17/03-01-05-02-02-01-17.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_17/03-01-06-02-01-01-17.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_17/03-01-08-01-02-02-17.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_17/03-01-06-02-01-02-17.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_17/03-01-08-02-01-01-17.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_17/03-01-02-01-02-01-17.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_17/03-01-05-02-02-02-17.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_17/03-01-03-02-02-01-17.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_17/03-01-04-01-01-02-17.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_17/03-01-02-01-01-01-17.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_17/03-01-05-02-01-01-17.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_17/03-01-06-02-02-02-17.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_17/03-01-03-01-01-01-17.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_17/03-01-08-02-01-02-17.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_17/03-01-01-01-01-02-17.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_17/03-01-03-01-02-01-17.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_17/03-01-04-01-02-01-17.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_17/03-01-02-01-01-02-17.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_17/03-01-02-01-02-02-17.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_17/03-01-08-02-02-02-17.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_17/03-01-08-02-02-01-17.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_17/03-01-04-02-02-01-17.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_17/03-01-08-01-01-02-17.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_17/03-01-07-01-02-02-17.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_17/03-01-08-01-01-01-17.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_17/03-01-04-01-02-02-17.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_17/03-01-06-01-02-01-17.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_17/03-01-01-01-01-01-17.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_17/03-01-01-01-02-02-17.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_17/03-01-05-01-01-01-17.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_17/03-01-04-02-02-02-17.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_17/03-01-03-01-02-02-17.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_17/03-01-04-02-01-01-17.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_17/03-01-02-02-01-02-17.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_17/03-01-01-01-02-01-17.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_17/03-01-03-02-01-01-17.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_17/03-01-04-02-01-02-17.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_17/03-01-06-01-01-02-17.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_17/03-01-03-02-01-02-17.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_04/03-01-03-02-02-01-04.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_04/03-01-07-01-01-02-04.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_04/03-01-08-01-02-01-04.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_04/03-01-03-02-01-02-04.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_04/03-01-08-02-02-02-04.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_04/03-01-04-01-01-01-04.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_04/03-01-01-01-01-01-04.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_04/03-01-02-02-01-01-04.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_04/03-01-05-02-01-02-04.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_04/03-01-06-01-02-02-04.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_04/03-01-04-02-01-01-04.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_04/03-01-08-01-01-01-04.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_04/03-01-03-02-01-01-04.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_04/03-01-04-01-02-02-04.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_04/03-01-08-02-01-02-04.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_04/03-01-07-01-02-01-04.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_04/03-01-04-01-02-01-04.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_04/03-01-04-02-02-01-04.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_04/03-01-02-02-02-02-04.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_04/03-01-05-01-01-01-04.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_04/03-01-04-02-02-02-04.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_04/03-01-03-01-02-01-04.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_04/03-01-02-01-01-02-04.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_04/03-01-02-01-01-01-04.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_04/03-01-01-01-01-02-04.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_04/03-01-05-02-01-01-04.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_04/03-01-07-02-01-02-04.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_04/03-01-07-02-01-01-04.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_04/03-01-06-01-01-02-04.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_04/03-01-01-01-02-02-04.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_04/03-01-06-02-01-02-04.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_04/03-01-03-01-02-02-04.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_04/03-01-07-01-02-02-04.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_04/03-01-05-01-02-02-04.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_04/03-01-03-01-01-01-04.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_04/03-01-03-01-01-02-04.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_04/03-01-07-02-02-02-04.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_04/03-01-07-01-01-01-04.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_04/03-01-05-02-02-02-04.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_04/03-01-06-01-02-01-04.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_04/03-01-08-02-01-01-04.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_04/03-01-06-01-01-01-04.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_04/03-01-05-01-01-02-04.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_04/03-01-07-02-02-01-04.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_04/03-01-02-01-02-02-04.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_04/03-01-02-01-02-01-04.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_04/03-01-08-01-02-02-04.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_04/03-01-06-02-01-01-04.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_04/03-01-02-02-02-01-04.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_04/03-01-04-02-01-02-04.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_04/03-01-03-02-02-02-04.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_04/03-01-06-02-02-01-04.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_04/03-01-02-02-01-02-04.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_04/03-01-05-01-02-01-04.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_04/03-01-06-02-02-02-04.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_04/03-01-08-02-02-01-04.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_04/03-01-08-01-01-02-04.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_04/03-01-01-01-02-01-04.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_04/03-01-05-02-02-01-04.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_04/03-01-04-01-01-02-04.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_01/03-01-02-01-01-02-01.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_01/03-01-06-02-02-02-01.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_01/03-01-02-01-02-01-01.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_01/03-01-08-01-01-01-01.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_01/03-01-05-02-02-02-01.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_01/03-01-06-01-02-01-01.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_01/03-01-02-02-01-02-01.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_01/03-01-04-01-02-02-01.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_01/03-01-02-01-02-02-01.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_01/03-01-01-01-02-02-01.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_01/03-01-08-02-01-01-01.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_01/03-01-02-02-01-01-01.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_01/03-01-08-01-02-02-01.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_01/03-01-07-02-02-02-01.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_01/03-01-07-01-01-01-01.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_01/03-01-03-02-02-02-01.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_01/03-01-03-02-01-02-01.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_01/03-01-06-02-02-01-01.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_01/03-01-06-01-02-02-01.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_01/03-01-03-01-02-01-01.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_01/03-01-06-01-01-02-01.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_01/03-01-07-01-01-02-01.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_01/03-01-02-02-02-01-01.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_01/03-01-08-01-02-01-01.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_01/03-01-05-01-01-01-01.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_01/03-01-07-02-02-01-01.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_01/03-01-05-02-01-02-01.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_01/03-01-03-01-01-02-01.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_01/03-01-07-02-01-02-01.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_01/03-01-06-02-01-01-01.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_01/03-01-06-02-01-02-01.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_01/03-01-05-01-02-02-01.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_01/03-01-03-01-01-01-01.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_01/03-01-08-02-02-02-01.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_01/03-01-04-01-01-01-01.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_01/03-01-07-01-02-01-01.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_01/03-01-04-02-01-02-01.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_01/03-01-02-02-02-02-01.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_01/03-01-04-01-02-01-01.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_01/03-01-07-02-01-01-01.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_01/03-01-01-01-01-02-01.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_01/03-01-08-02-02-01-01.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_01/03-01-05-01-01-02-01.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_01/03-01-01-01-01-01-01.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_01/03-01-05-02-01-01-01.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_01/03-01-04-02-02-02-01.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_01/03-01-08-02-01-02-01.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_01/03-01-06-01-01-01-01.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_01/03-01-07-01-02-02-01.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_01/03-01-03-01-02-02-01.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_01/03-01-04-02-01-01-01.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_01/03-01-01-01-02-01-01.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_01/03-01-05-02-02-01-01.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_01/03-01-04-01-01-02-01.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_01/03-01-04-02-02-01-01.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_01/03-01-08-01-01-02-01.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_01/03-01-03-02-01-01-01.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_01/03-01-03-02-02-01-01.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_01/03-01-05-01-02-01-01.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_01/03-01-02-01-01-01-01.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_06/03-01-01-01-01-01-06.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_06/03-01-07-01-02-02-06.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_06/03-01-08-01-01-02-06.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_06/03-01-07-02-02-01-06.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_06/03-01-04-02-02-02-06.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_06/03-01-05-02-02-01-06.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_06/03-01-03-01-02-01-06.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_06/03-01-04-01-02-02-06.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_06/03-01-02-02-01-01-06.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_06/03-01-03-02-01-01-06.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_06/03-01-03-02-02-01-06.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_06/03-01-01-01-01-02-06.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_06/03-01-07-02-01-01-06.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_06/03-01-04-02-01-02-06.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_06/03-01-02-01-01-02-06.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_06/03-01-08-01-02-02-06.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_06/03-01-03-01-01-01-06.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_06/03-01-08-02-01-01-06.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_06/03-01-02-01-01-01-06.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_06/03-01-03-01-01-02-06.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_06/03-01-06-02-01-02-06.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_06/03-01-02-02-01-02-06.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_06/03-01-02-02-02-01-06.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_06/03-01-02-01-02-01-06.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_06/03-01-04-01-01-02-06.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_06/03-01-08-02-02-01-06.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_06/03-01-04-01-01-01-06.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_06/03-01-06-01-02-02-06.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_06/03-01-07-02-02-02-06.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_06/03-01-08-02-01-02-06.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_06/03-01-05-02-01-01-06.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_06/03-01-06-02-02-02-06.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_06/03-01-06-02-01-01-06.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_06/03-01-05-02-01-02-06.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_06/03-01-04-02-01-01-06.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_06/03-01-05-02-02-02-06.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_06/03-01-07-01-01-01-06.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_06/03-01-05-01-01-02-06.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_06/03-01-02-02-02-02-06.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_06/03-01-07-01-01-02-06.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_06/03-01-01-01-02-02-06.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_06/03-01-06-02-02-01-06.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_06/03-01-08-01-02-01-06.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_06/03-01-05-01-02-02-06.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_06/03-01-03-01-02-02-06.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_06/03-01-06-01-01-02-06.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_06/03-01-05-01-01-01-06.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_06/03-01-04-02-02-01-06.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_06/03-01-03-02-01-02-06.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_06/03-01-08-01-01-01-06.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_06/03-01-04-01-02-01-06.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_06/03-01-06-01-01-01-06.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_06/03-01-08-02-02-02-06.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_06/03-01-03-02-02-02-06.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_06/03-01-02-01-02-02-06.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_06/03-01-06-01-02-01-06.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_06/03-01-01-01-02-01-06.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_06/03-01-07-01-02-01-06.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_06/03-01-07-02-01-02-06.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_06/03-01-05-01-02-01-06.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_20/03-01-07-01-01-02-20.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_20/03-01-04-02-01-02-20.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_20/03-01-07-02-01-02-20.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_20/03-01-04-02-02-02-20.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_20/03-01-03-01-01-01-20.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_20/03-01-02-01-01-02-20.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_20/03-01-04-02-02-01-20.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_20/03-01-03-01-02-02-20.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_20/03-01-04-01-02-02-20.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_20/03-01-04-02-01-01-20.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_20/03-01-08-01-02-02-20.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_20/03-01-05-02-02-01-20.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_20/03-01-08-01-02-01-20.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_20/03-01-03-02-01-02-20.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_20/03-01-06-01-01-02-20.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_20/03-01-06-02-02-01-20.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_20/03-01-07-02-02-01-20.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_20/03-01-02-02-02-01-20.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_20/03-01-01-01-02-01-20.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_20/03-01-08-02-01-02-20.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_20/03-01-08-02-02-01-20.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_20/03-01-03-02-02-02-20.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_20/03-01-05-01-01-02-20.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_20/03-01-05-01-02-02-20.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_20/03-01-03-02-02-01-20.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_20/03-01-04-01-01-01-20.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_20/03-01-08-02-01-01-20.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_20/03-01-02-02-01-02-20.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_20/03-01-07-02-02-02-20.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_20/03-01-03-01-01-02-20.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_20/03-01-05-01-01-01-20.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_20/03-01-08-01-01-02-20.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_20/03-01-02-01-02-02-20.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_20/03-01-07-01-02-02-20.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_20/03-01-03-01-02-01-20.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_20/03-01-01-01-02-02-20.wav
# Train /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_20/03-01-01-01-01-01-20.wav
# ...
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_15/03-01-05-01-02-02-15.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_15/03-01-03-01-02-01-15.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_15/03-01-06-02-01-02-15.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_15/03-01-05-01-02-01-15.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_15/03-01-04-02-01-01-15.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_15/03-01-02-02-02-02-15.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_15/03-01-03-01-02-02-15.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_15/03-01-07-01-01-02-15.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_15/03-01-01-01-01-01-15.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_15/03-01-06-01-01-01-15.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_15/03-01-02-01-01-02-15.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_15/03-01-08-02-01-02-15.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_15/03-01-03-02-02-01-15.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_15/03-01-08-02-01-01-15.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_15/03-01-02-02-01-01-15.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_15/03-01-07-01-02-01-15.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_15/03-01-04-02-02-01-15.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_15/03-01-03-02-01-01-15.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_15/03-01-08-01-02-01-15.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_15/03-01-03-01-01-02-15.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_15/03-01-02-01-02-01-15.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_15/03-01-06-02-02-01-15.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_15/03-01-03-02-01-02-15.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_15/03-01-07-01-02-02-15.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_15/03-01-02-01-01-01-15.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_15/03-01-04-01-02-02-15.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_15/03-01-04-02-02-02-15.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_15/03-01-07-02-01-01-15.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_15/03-01-06-02-02-02-15.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_15/03-01-05-02-01-01-15.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_15/03-01-01-01-02-02-15.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_15/03-01-08-01-02-02-15.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_15/03-01-07-01-01-01-15.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_09/03-01-06-02-02-02-09.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_09/03-01-01-01-02-01-09.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_09/03-01-02-01-02-02-09.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_09/03-01-07-01-02-02-09.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_09/03-01-03-01-01-02-09.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_09/03-01-06-02-01-01-09.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_09/03-01-08-01-02-01-09.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_09/03-01-02-02-02-01-09.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_09/03-01-08-01-01-02-09.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_09/03-01-08-02-01-02-09.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_09/03-01-06-01-01-01-09.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_09/03-01-03-01-02-02-09.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_09/03-01-05-01-02-01-09.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_09/03-01-03-02-02-01-09.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_09/03-01-04-01-02-02-09.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_09/03-01-02-02-01-01-09.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_09/03-01-08-02-01-01-09.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_09/03-01-07-01-01-01-09.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_09/03-01-02-01-02-01-09.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_09/03-01-03-02-01-02-09.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_09/03-01-05-01-01-01-09.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_09/03-01-04-01-01-01-09.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_09/03-01-07-02-01-02-09.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_09/03-01-06-01-01-02-09.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_09/03-01-01-01-01-02-09.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_09/03-01-08-02-02-01-09.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_09/03-01-04-02-01-01-09.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_09/03-01-02-01-01-01-09.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_09/03-01-07-02-01-01-09.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_09/03-01-05-01-01-02-09.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_09/03-01-04-02-02-01-09.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_09/03-01-05-01-02-02-09.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_09/03-01-03-01-01-01-09.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_09/03-01-04-02-02-02-09.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_09/03-01-03-02-02-02-09.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_09/03-01-06-02-02-01-09.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_09/03-01-05-02-01-01-09.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_09/03-01-08-01-01-01-09.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_09/03-01-03-01-02-01-09.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_09/03-01-05-02-02-01-09.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_09/03-01-01-01-01-01-09.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_09/03-01-02-02-02-02-09.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_09/03-01-07-01-01-02-09.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_09/03-01-06-01-02-02-09.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_09/03-01-04-02-01-02-09.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_09/03-01-05-02-02-02-09.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_09/03-01-01-01-02-02-09.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_09/03-01-06-01-02-01-09.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_09/03-01-08-01-02-02-09.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_09/03-01-02-02-01-02-09.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_09/03-01-04-01-02-01-09.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_09/03-01-07-02-02-02-09.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_09/03-01-08-02-02-02-09.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_09/03-01-03-02-01-01-09.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_09/03-01-02-01-01-02-09.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_09/03-01-07-01-02-01-09.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_09/03-01-07-02-02-01-09.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_09/03-01-04-01-01-02-09.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_09/03-01-06-02-01-02-09.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_09/03-01-05-02-01-02-09.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_10/03-01-07-01-02-02-10.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_10/03-01-03-01-02-02-10.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_10/03-01-05-02-02-02-10.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_10/03-01-07-01-01-02-10.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_10/03-01-04-02-02-01-10.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_10/03-01-04-02-01-02-10.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_10/03-01-07-02-02-01-10.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_10/03-01-08-01-01-01-10.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_10/03-01-04-01-01-02-10.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_10/03-01-08-01-02-01-10.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_10/03-01-05-01-01-02-10.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_10/03-01-03-01-01-02-10.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_10/03-01-03-01-01-01-10.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_10/03-01-07-02-02-02-10.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_10/03-01-02-01-01-02-10.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_10/03-01-06-01-01-01-10.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_10/03-01-07-01-02-01-10.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_10/03-01-01-01-01-02-10.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_10/03-01-05-01-02-01-10.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_10/03-01-07-02-01-02-10.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_10/03-01-02-01-01-01-10.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_10/03-01-02-02-02-02-10.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_10/03-01-08-02-01-02-10.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_10/03-01-06-02-02-01-10.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_10/03-01-08-02-02-02-10.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_10/03-01-02-02-01-01-10.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_10/03-01-08-02-02-01-10.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_10/03-01-06-02-01-02-10.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_10/03-01-03-01-02-01-10.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_10/03-01-06-02-01-01-10.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_10/03-01-04-01-02-01-10.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_10/03-01-04-01-02-02-10.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_10/03-01-01-01-02-02-10.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_10/03-01-03-02-02-02-10.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_10/03-01-06-01-01-02-10.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_10/03-01-07-01-01-01-10.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_10/03-01-02-01-02-02-10.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_10/03-01-07-02-01-01-10.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_10/03-01-05-02-02-01-10.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_10/03-01-05-02-01-01-10.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_10/03-01-01-01-02-01-10.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_10/03-01-08-02-01-01-10.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_10/03-01-05-02-01-02-10.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_10/03-01-03-02-01-01-10.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_10/03-01-04-02-02-02-10.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_10/03-01-02-01-02-01-10.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_10/03-01-06-02-02-02-10.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_10/03-01-04-02-01-01-10.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_10/03-01-05-01-01-01-10.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_10/03-01-02-02-02-01-10.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_10/03-01-04-01-01-01-10.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_10/03-01-02-02-01-02-10.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_10/03-01-08-01-02-02-10.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_10/03-01-03-02-01-02-10.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_10/03-01-05-01-02-02-10.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_10/03-01-06-01-02-02-10.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_10/03-01-03-02-02-01-10.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_10/03-01-01-01-01-01-10.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_10/03-01-08-01-01-02-10.wav
# Test /home/onkar27/testing_1/myvenv/archive/audio_speech_actors_01-24/Actor_10/03-01-06-01-02-01-10.wav

# %% [markdown]
# <h2>Loading the High Dimensional Data from EmuCore</h2>
# Import Libraries:
#
# These are the tools we'll use for building machine learning models and handling data.
# sklearn is a popular library for machine learning in Python.
# numpy is used for working with numerical data.
# Define Possible Values:
#
# These lists define possible categories or labels for certain features in your dataset.
# They help in understanding or classifying the data.
# Load Data:
#
# We read the training and testing data from files that were saved earlier.
# The np.load function is used to load the data, and allow_pickle=True lets us read Python objects stored in the files.
# .item() converts the loaded data into a dictionary so that we can easily work with it.

# %%
# Import necessary libraries for machine learning and numerical operations
import os
import sys
from sklearn.linear_model import (
    LinearRegression,
    LogisticRegression,
)  # For linear and logistic regression models
from sklearn.metrics import accuracy_score  # To measure the accuracy of our models
from sklearn.ensemble import RandomForestClassifier  # For random forest classification
from sklearn.tree import DecisionTreeClassifier  # For decision tree classification
from sklearn.svm import SVC  # For support vector classification
import numpy as np  # For handling numerical data

# Define possible values for certain features
STATEMENTS = ["01", "02"]  # Different statements in the dataset
INTENSITIES = ["01", "02"]  # Different intensity levels in the dataset
REPETITIONS = ["01", "02"]  # Different repetitions in the dataset

# Load the training and testing data from saved files
train_set = np.load(
    "train_set_ravdess_reservoir2.npy",  # File containing training data
    allow_pickle=True,  # Allows loading of Python objects from the file
).item()  # Convert the loaded data to a Python dictionary

test_set = np.load(
    "test_set_ravdess_reservoir2.npy",  # File containing testing data
    allow_pickle=True,  # Allows loading of Python objects from the file
).item()  # Convert the loaded data to a Python dictionary

# %% [markdown]
# Initialize Variables:
#
# X_train will store all the cochleagram data (features) from the training set.
# y_train will store all the corresponding labels for the training data.
# Loop Through Each Training File:
#
# For each file in the training set, get the cochleagram data (features) and labels.
# Concatenate Data:
#
# If X_train is empty, start it with the current cochleagram data.
# If X_train already has data, add the current cochleagram data to it.
# Similarly, handle y_train by repeating and concatenating labels to match the cochleagram data.
# Label Adjustment:
#
# Adjust labels to be in the range of {-1, 1} for consistency in some machine learning models.
# Use np.repeat to match the shape of the cochleagram data.

# %%
# Initialize variables to store training data and labels
X_train = None  # This will hold the concatenated feature data for training
y_train = None  # This will hold the concatenated labels for training

# Loop through each file in the training dataset
for file_name in train_set.keys():

    # Get the cochleagram data for the current file
    coch = train_set[file_name]["coch"]

    # If X_train is empty, initialize it with the current cochleagram data
    if X_train is None:
        X_train = coch
    else:
        # If X_train already has data, add the current cochleagram data to it
        X_train = np.concatenate([X_train, coch])

    # Get the label for the current file, adjust it to be in the range {-1, 1}
    label = train_set[file_name]["label"] * 2 - 1

    # Repeat the label to match the shape of the cochleagram data
    labels = np.repeat(label.reshape(-1, 1), coch.shape[0], axis=1).T

    # If y_train is empty, initialize it with the current labels
    if y_train is None:
        y_train = labels
    else:
        # If y_train already has data, add the current labels to it
        y_train = np.concatenate([y_train, labels])

# %% [markdown]
# <h2>Create a Linear Regression Model:</h2>
#
# LinearRegression(fit_intercept=True): This line creates a linear regression model object. The fit_intercept=True means the model will include an intercept in the regression line.
# Train the Model:
#
# clf.fit(X_train, y_train): This trains the model using your training data (X_train) and the corresponding labels (y_train). Essentially, it learns the relationship between the features and the labels.
# Evaluate the Model:
#
# score = clf.score(X_train, y_train): This measures how well the trained model performs on the training data. The score typically ranges from 0 to 1, where 1 means perfect prediction and 0 means the model is no better than random guessing.

# %%
from sklearn.linear_model import LinearRegression

# Create a Linear Regression model
clf = LinearRegression(fit_intercept=True)

# Train the model using the training data and labels
clf.fit(X_train, y_train)

# Evaluate the model's performance on the training data
score = clf.score(X_train, y_train)

# %% [markdown]
# <h2>Process Training Data:</h2>
#
# Initialize Lists: y_train to store true labels and y_train_prd to store predicted values for the training data.
# Filter and Process: For each file, check if it meets the criteria (repetition, statement, intensity). If it does, append the true label and the model’s prediction (average over features) to the lists.
# Evaluate Training Data:
#
# Calculate and print the success rate (accuracy) for the training data using WSR_MSE, which measures how well the predictions match the actual labels.
# Process Test Data:
#
# Initialize Lists: y_test for true labels and y_test_prd for predicted values for the test data.
# Filter and Process: For each file, check if it meets the criteria (similar to training data). Append the true label and the model’s prediction to the lists.
# Evaluate Test Data:
#
# Calculate and print the success rate (accuracy) for the test data using WSR_MSE, similar to the training data evaluation.

# %%
# Lists to store actual labels and predicted values for training data
y_train = []
y_train_prd = []

# Process each file in the training dataset
for file_name in train_set.keys():

    # Get the base name of the file (remove the file extension)
    base_name = file_name.split(".")[0]

    # Skip files that do not match the expected criteria
    if base_name.split("-")[5] not in REPETITIONS:
        continue
    if base_name.split("-")[4] not in STATEMENTS:
        continue
    if base_name.split("-")[3] not in INTENSITIES:
        continue

    # Get the features (cochleagrams) and append the label
    X_train_tmp = train_set[file_name]["coch"]
    X_train_tmp = np.array(X_train_tmp)  # Convert to numpy array
    y_train.append(train_set[file_name]["label"] * 2 - 1)

    # Predict using the model and take the average prediction for the features
    y_train_prd.append(clf.predict(X_train_tmp).mean(axis=0))

# Print the success rate on the training data
print(
    "Success rate on train data: %0.3f"
    % (WSR_MSE(y_train, y_train_prd))  # This function computes the error rate
)

# Lists to store actual labels and predicted values for test data
y_test = []
y_test_prd = []

# Process each file in the test dataset
for file_name in test_set.keys():

    # Get the base name of the file (remove the file extension)
    base_name = file_name.split(".")[0]

    # Skip files that do not match the expected criteria
    if base_name.split("-")[5] not in REPETITIONS:
        continue
    if base_name.split("-")[4] not in STATEMENTS:
        continue
    if base_name.split("-")[3] not in INTENSITIES:
        continue

    # Get the features (cochleagrams) and append the label
    X_test_tmp = test_set[file_name]["coch"]
    y_test.append(test_set[file_name]["label"] * 2 - 1)

    # Predict using the model and take the average prediction for the features
    y_test_prd.append(clf.predict(X_test_tmp).mean(axis=0))

# Print the success rate on the test data
print(
    "Success rate on test data: %0.3f"
    % (WSR_MSE(y_test, y_test_prd))  # This function computes the error rate
)
# Out:
# Success rate on train data: 0.654
# Success rate on test data: 0.517
